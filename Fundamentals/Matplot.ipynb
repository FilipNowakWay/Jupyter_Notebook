# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
lista = [1.231,23.1,23.1,0.12,26.1,678,1.2,21]
plt.plot(lista);

# %%
x = [1,53,32,12,98]
y = [54,21,52,1,2]
x,y
# Out:
# ([1, 53, 32, 12, 98], [54, 21, 52, 1, 2])

# %%
plt.plot(x,y)

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots(figsize=(10,6))
plot = ax.plot(x,y)

ax.set(title="Simple sample plot",
      xlabel="X axis",
      ylabel="Y axis")
# Out:
# [Text(0.5, 1.0, 'Simple sample plot'),
#  Text(0.5, 0, 'X axis'),
#  Text(0, 0.5, 'Y axis')]

# %%
x = np.linspace(0, 10, 100)

# %%
fig, ax = plt.subplots(figsize=(10,6))
plot = ax.plot(x,pow(x,2))

# %% [markdown]
# # Scatter plots

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x,np.exp(x))

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x, np.sin(x))

# %%
ulubione_jedzenie = {"Burger": 30,
                    "Lody": 10,
                    "Czekolada": 4,
                    "Pizza": 25}
fig, ax = plt.subplots()
ax.bar (ulubione_jedzenie.keys(), ulubione_jedzenie.values())
ax.set(title="Moje ulubione jedzenie",
      ylabel="Cena (Zł)");

# %%
ulubione_jedzenie = {"Burger": 30,
                    "Lody": 10,
                    "Czekolada": 4,
                    "Pizza": 25}
fig, ax = plt.subplots()
ax.barh (list(ulubione_jedzenie.keys()), list(ulubione_jedzenie.values()))
ax.set(title="Moje ulubione jedzenie",
      ylabel="Cena (Zł)");

# %%
x = np.random.randn(1000)
fig, ax= plt.subplots()
ax.hist(x)
# Out:
# (array([ 12.,  27.,  81., 174., 234., 230., 136.,  79.,  23.,   4.]),
#  array([-3.01787832e+00, -2.41412353e+00, -1.81036874e+00, -1.20661395e+00,
#         -6.02859154e-01,  8.95637606e-04,  6.04650429e-01,  1.20840522e+00,
#          1.81216001e+00,  2.41591480e+00,  3.01966960e+00]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.rand(1000)
fig, ax = plt.subplots()
plt.hist(x)
# Out:
# (array([ 99., 102., 119.,  92., 100.,  94.,  92., 113.,  91.,  98.]),
#  array([3.40862472e-04, 1.00108099e-01, 1.99875336e-01, 2.99642573e-01,
#         3.99409810e-01, 4.99177047e-01, 5.98944284e-01, 6.98711521e-01,
#         7.98478757e-01, 8.98245994e-01, 9.98013231e-01]),
#  <BarContainer object of 10 artists>)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(10,5),
                                             nrows=2,
                                             ncols=2)
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(ulubione_jedzenie.keys(),ulubione_jedzenie.values())
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # Pandas DF + Plots

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14756/2847182809.py in <module>
# ----> 1 car_sales["Price"].plot()
#
# ~\Documents\HUB\sample_project_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Documents\HUB\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
# Out:
# C:\Users\Wungi\AppData\Local\Temp/ipykernel_14756/1206353097.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales["Sale Date"] = pd.date_range("3/6/2022", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2022-03-06
# 1   Honda    Red          87899      4   5000         9000 2022-03-07
# 2  Toyota   Blue          32549      3   7000        16000 2022-03-08
# 3     BMW  Black          11179      5  22000        38000 2022-03-09
# 4  Nissan  White         213095      4   3500        41500 2022-03-10
# 5  Toyota  Green          99213      4   4500        46000 2022-03-11
# 6   Honda   Blue          45698      4   7500        53500 2022-03-12
# 7   Honda   Blue          54738      4   7000        60500 2022-03-13
# 8  Toyota  White          60000      4   6250        66750 2022-03-14
# 9  Nissan  White          31600      4   9700        76450 2022-03-15

# %%
car_sales.plot(x = "Sale Date", y = "Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.60103522, 0.02154171, 0.77175977, 0.20375498],
#        [0.0748744 , 0.69626253, 0.16562493, 0.06811424],
#        [0.06054839, 0.55835959, 0.51703766, 0.51944024],
#        [0.58913704, 0.70658582, 0.40757434, 0.40468727],
#        [0.44611919, 0.87769967, 0.78028734, 0.75600626],
#        [0.25187303, 0.05040253, 0.02172014, 0.66963796],
#        [0.99024867, 0.74581093, 0.34646756, 0.06728673],
#        [0.47613897, 0.64088382, 0.45844897, 0.81073065],
#        [0.19014133, 0.8873481 , 0.68302839, 0.97674357],
#        [0.30585486, 0.78312349, 0.33087917, 0.52294481]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Price"].plot(kind='hist', bins=20);

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease["age"].plot(kind='hist',bins=50);

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
over_50 = heart_disease[heart_disease['age']>50]

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x = over_50["age"],
                     y = over_50['chol'],
                     c = over_50['target'])

ax.set(title="Heart Disease and cholesterol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-whitegrid")

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x = over_50["age"],
                     y = over_50['chol'],
                     c = over_50['target'])

ax.set(title="Heart Disease and cholesterol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x = over_50["age"],
                     y = over_50['chol'],
                     c = over_50['target'],
                    cmap="winter")

ax.set(title="Heart Disease and cholesterol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(),
          linestyle='--',
          color='red');

# %%
fig.savefig("../matplotlib-heart-disease-chol-age-plot-saved.png")
